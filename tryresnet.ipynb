# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
run keras_title_projattention_res.py
# Out:
# maxlen 30 epoch 10 dim_lstm 200
# dim_Dense 50
# dropout_rate 0.0 , LSTM type: bi-lstm sum
# Activation function: ['relu', 'relu', 'relu']
# bias of y: 0
# loss_function: mse
# start: 0 end:
# ------------------------------
# Reading English Data: 72043
# Reading jp Data: 72043
# Merging the English and Japanes news dataframe...
# Drop the null line...
# False    72031
# True        12
# Name: en_article, dtype: int64
# Using the new test data to evaluate.......
# /home/R2016hwang/research/keras_title_projattention_res.py:437: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if type(translation_matrix) != type(None):
# /home/R2016hwang/research/keras_title_projattention_res.py:443: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   else:
# /home/R2016hwang/research/keras_title_projattention_res.py:598: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # df_pairs_evaluate['word2vec_en_wrong'] = df_pairs_evaluate['en_article_wrong'].apply(doc2embed, args=(model_en,))
# /home/R2016hwang/research/keras_title_projattention_res.py:441: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   else:
# /home/R2016hwang/research/keras_title_projattention_res.py:600: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/R2016hwang/research/keras_title_projattention_res.py:602: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # df_pairs_evaluate['padding_en_wrong'] = df_pairs_evaluate['word2vec_en_wrong'].apply(padding, args=(TIME_STEP,))
# /home/R2016hwang/research/keras_title_projattention_res.py:604: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/R2016hwang/research/keras_title_projattention_res.py:615: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # df_pairs_sample['word2vec_en_wrong'] = df_pairs_sample['en_article_wrong'].apply(doc2embed, args=(model_en,))
# /home/R2016hwang/research/keras_title_projattention_res.py:617: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 长度为零
# 长度为零
# 长度为零
# 长度为零
# 长度为零
# 长度为零
# 长度为零
# /home/R2016hwang/research/keras_title_projattention_res.py:620: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # df_pairs_sample['padding_en_wrong'] = df_pairs_sample['word2vec_en_wrong'].apply(padding, args=(TIME_STEP,))
# /home/R2016hwang/research/keras_title_projattention_res.py:622: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C value = 12 position: [26, 51, 3635, 5754, 15514, 16501, 16725, 23261, 26042, 33771, 34633, 46537]
# /home/R2016hwang/research/keras_title_projattention_res.py:745: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("ma...)`
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input_1 (InputLayer)       (None, 30, 200)      0
# __________________________________________________________________________________________________
# main_input_2 (InputLayer)       (None, 30, 200)      0
# __________________________________________________________________________________________________
# bidirectional_63 (Bidirectional (None, 30, 200)      641600      main_input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_64 (Bidirectional (None, 30, 200)      641600      main_input_2[0][0]
# __________________________________________________________________________________________________
# dot_125 (Dot)                   (None, 30, 30)       0           bidirectional_63[0][0]
#                                                                  bidirectional_64[0][0]
# __________________________________________________________________________________________________
# dot_126 (Dot)                   (None, 30, 30)       0           bidirectional_64[0][0]
#                                                                  bidirectional_63[0][0]
# __________________________________________________________________________________________________
# dot_127 (Dot)                   (None, 30, 200)      0           dot_125[0][0]
#                                                                  bidirectional_64[0][0]
# __________________________________________________________________________________________________
# dot_128 (Dot)                   (None, 30, 200)      0           dot_126[0][0]
#                                                                  bidirectional_63[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 200)          0           bidirectional_63[0][0]
#                                                                  bidirectional_64[0][0]
#                                                                  dot_127[0][0]
#                                                                  dot_128[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 800)          0           lambda_32[0][0]
#                                                                  lambda_32[2][0]
#                                                                  lambda_32[1][0]
#                                                                  lambda_32[3][0]
# __________________________________________________________________________________________________
# dense_94 (Dense)                (None, 200)          160200      concatenate_32[0][0]
# __________________________________________________________________________________________________
# dense_95 (Dense)                (None, 200)          160200      concatenate_32[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 200)          0           dense_94[0][0]
#                                                                  dense_95[0][0]
# __________________________________________________________________________________________________
# dense_96 (Dense)                (None, 50)           10050       add_32[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 50)           0           dense_96[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 1)            51          dropout_32[0][0]
# ==================================================================================================
# Total params: 1,613,701
# Trainable params: 1,613,701
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch:  1 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 19s 2ms/step - loss: 2.5196 - val_loss: 0.3695
# Data parts  2 / 10 ----------------------------------------
#
# C value = 2 position: [307, 661]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2856 - val_loss: 0.2401
# Data parts  3 / 10 ----------------------------------------
#
# C value = 2 position: [44, 143]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 15s 2ms/step - loss: 11.2519 - val_loss: 1.7523
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [156]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 16s 2ms/step - loss: 1.0300 - val_loss: 0.5465
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [600]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.3994 - val_loss: 0.4497
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.3146 - val_loss: 0.2826
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [109]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.3587 - val_loss: 0.7291
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2997 - val_loss: 0.2517
# Data parts  9 / 10 ----------------------------------------
#
# C value = 3 position: [540, 588, 603]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2474 - val_loss: 0.3210
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [874]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2347 - val_loss: 0.2166
# Find ranking of  1000  sentence pairs
# /home/R2016hwang/research/keras_title_projattention_res.py:184: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   model_1 = Model(input=[input_1, input_2], output=[lstm_out_1, lstm_out_2])
# /home/R2016hwang/research/keras_title_projattention_res.py:280: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("ma...)`
#   model_2 = Model(input=[input_1, input_2], output=main_output)
# Use Time(s):  100.9345338344574
# [T] TOP 1 6
# [T] TOP 5 30
# [T] TOP 10 76
# Epoch:  2 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [898]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1951 - val_loss: 0.1807
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [450]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1770 - val_loss: 0.1940
# Data parts  3 / 10 ----------------------------------------
#
# C value = 2 position: [487, 578]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 18s 2ms/step - loss: 5.1836 - val_loss: 0.2876
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [424, 494]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2567 - val_loss: 0.2262
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [3, 987]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2351 - val_loss: 0.2812
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [472]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2045 - val_loss: 0.2177
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [234]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2286 - val_loss: 0.3628
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [202, 942]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1878 - val_loss: 0.1842
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [794]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1725 - val_loss: 0.1879
# Data parts  10 / 10 ----------------------------------------
#
# C value = 4 position: [249, 476, 733, 772]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1592 - val_loss: 0.1665
# Find ranking of  1000  sentence pairs
# Use Time(s):  92.32977819442749
# [T] TOP 1 14
# [T] TOP 5 75
# [T] TOP 10 144
# Epoch:  3 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1546 - val_loss: 0.1476
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1442 - val_loss: 0.1531
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [596]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.1829 - val_loss: 0.1281
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.1211 - val_loss: 0.1320
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [488, 980]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1316 - val_loss: 0.1653
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.1207 - val_loss: 0.1352
# Data parts  7 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1158 - val_loss: 0.1815
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [603]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1156 - val_loss: 0.1224
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [531]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.1067 - val_loss: 0.1394
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [715]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1015 - val_loss: 0.1186
# Find ranking of  1000  sentence pairs
# Use Time(s):  92.35145020484924
# [T] TOP 1 21
# [T] TOP 5 141
# [T] TOP 10 248
# Epoch:  4 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [405, 599]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0962 - val_loss: 0.1066
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.1051 - val_loss: 0.1193
# Data parts  3 / 10 ----------------------------------------
#
# C value = 3 position: [153, 237, 319]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 1.4121 - val_loss: 0.6054
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [242, 662]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.3681 - val_loss: 0.2212
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [385]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.5793 - val_loss: 0.2893
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [715]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2819 - val_loss: 0.2589
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [911]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2545 - val_loss: 0.2520
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [125, 593]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2511 - val_loss: 0.2504
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 2 position: [727, 987]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2499 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  96.14396953582764
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  5 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [184, 214]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2502 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [200, 992]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2489 - val_loss: 0.2505
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [864]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 14s 2ms/step - loss: 0.2508 - val_loss: 0.2501
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [65]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 2 position: [23, 61]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2491 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [415, 523]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 3 position: [114, 246, 965]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2499 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 2 position: [479, 598]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2483 - val_loss: 0.2502
# Find ranking of  1000  sentence pairs
# Use Time(s):  97.07324457168579
# [T] TOP 1 1
# [T] TOP 5 3
# [T] TOP 10 4
# Epoch:  6 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2502 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 2 position: [190, 880]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [344]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2465 - val_loss: 0.2505
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [534]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2496 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2490 - val_loss: 0.2502
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [926]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2499 - val_loss: 0.2503
# Data parts  9 / 10 ----------------------------------------
#
# C value = 2 position: [200, 243]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2497 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [224]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  97.02938485145569
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  7 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [457]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 2 position: [602, 606]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2499
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2483 - val_loss: 0.2505
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [600]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2478 - val_loss: 0.2502
# Data parts  6 / 10 ----------------------------------------
#
# C value = 3 position: [582, 605, 780]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2499 - val_loss: 0.2498
# Data parts  7 / 10 ----------------------------------------
#
# C value = 2 position: [185, 966]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2484 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 5 position: [552, 582, 605, 719, 720]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2443 - val_loss: 0.2357
# Data parts  9 / 10 ----------------------------------------
#
# C value = 3 position: [171, 598, 983]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2341 - val_loss: 0.2337
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2647 - val_loss: 0.2512
# Find ranking of  1000  sentence pairs
# Use Time(s):  99.25876474380493
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  8 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [958]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2511 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 2 position: [382, 876]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2498
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [673]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [364]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2498
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [966]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2504 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [690]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2504 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [307]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  99.84947276115417
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  9 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 2 position: [299, 980]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 16s 2ms/step - loss: 3644.5857 - val_loss: 0.6167
# Data parts  4 / 10 ----------------------------------------
#
# C value = 4 position: [388, 720, 962, 994]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.5353 - val_loss: 0.5536
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [118, 594]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.6592 - val_loss: 0.3797
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [110, 996]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.5483 - val_loss: 0.3585
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [602]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.5104 - val_loss: 0.3072
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [464]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.3385 - val_loss: 0.3931
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [598]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.3151 - val_loss: 0.3016
# Data parts  10 / 10 ----------------------------------------
#
# C value = 2 position: [330, 515]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.3258 - val_loss: 0.3228
# Find ranking of  1000  sentence pairs
# Use Time(s):  100.95201373100281
# [T] TOP 1 2
# [T] TOP 5 7
# [T] TOP 10 20
# Epoch:  10 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [681, 874]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2792 - val_loss: 0.2572
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.3048 - val_loss: 0.3525
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [84]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.3081 - val_loss: 0.2587
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2827 - val_loss: 0.2379
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [154, 961]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2772 - val_loss: 0.2581
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [156]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2707 - val_loss: 0.2641
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [204]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2696 - val_loss: 0.2658
# Data parts  8 / 10 ----------------------------------------
#
# C value = 5 position: [138, 179, 356, 601, 842]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2422 - val_loss: 0.2747
# Data parts  9 / 10 ----------------------------------------
#
# C value = 3 position: [22, 642, 775]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2845 - val_loss: 0.2392
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [476]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2510 - val_loss: 0.2877
# Find ranking of  1000  sentence pairs
# Use Time(s):  97.8525230884552
# [T] TOP 1 2
# [T] TOP 5 13
# [T] TOP 10 30
# Epoch:  11 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [197]
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2744 - val_loss: 0.2199
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2414 - val_loss: 0.3087
# Data parts  3 / 10 ----------------------------------------
#
# C value = 2 position: [308, 929]
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2390 - val_loss: 0.2227
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [151]
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2369 - val_loss: 0.2256
# Data parts  5 / 10 ----------------------------------------
#
# C value = 3 position: [4, 388, 818]
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2401 - val_loss: 0.3190
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2707 - val_loss: 0.2316
# Data parts  7 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2248 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [763, 999]
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2174 - val_loss: 0.2515
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2412 - val_loss: 0.2520
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2300 - val_loss: 0.2089
# Find ranking of  1000  sentence pairs
# Use Time(s):  103.52827858924866
# [T] TOP 1 3
# [T] TOP 5 25
# [T] TOP 10 44
# Epoch:  12 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2332 - val_loss: 0.1982
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2329 - val_loss: 0.2222
# Data parts  3 / 10 ----------------------------------------
#
# C value = 3 position: [26, 550, 600]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2132 - val_loss: 0.2207
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [497]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2166 - val_loss: 0.1981
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [219, 605]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2388 - val_loss: 0.2095
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [96]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2256 - val_loss: 0.2554
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [431]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2124 - val_loss: 0.2567
# Data parts  8 / 10 ----------------------------------------
#
# C value = 3 position: [472, 594, 606]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2022 - val_loss: 0.2197
# Data parts  9 / 10 ----------------------------------------
#
# C value = 2 position: [218, 497]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2175 - val_loss: 0.2139
# Data parts  10 / 10 ----------------------------------------
#
# C value = 4 position: [56, 88, 125, 865]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2224 - val_loss: 0.1917
# Find ranking of  1000  sentence pairs
# Use Time(s):  96.1204662322998
# [T] TOP 1 5
# [T] TOP 5 34
# [T] TOP 10 58
# Epoch:  13 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2514 - val_loss: 0.1815
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1957 - val_loss: 0.2175
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [749]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2145 - val_loss: 0.2253
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [299, 873]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2206 - val_loss: 0.2170
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [299, 602]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2120 - val_loss: 0.1839
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2214 - val_loss: 0.4699
# Data parts  7 / 10 ----------------------------------------
#
# C value = 2 position: [30, 816]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2042 - val_loss: 0.2293
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1984 - val_loss: 0.2124
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2007 - val_loss: 0.1971
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [656]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1874 - val_loss: 0.1795
# Find ranking of  1000  sentence pairs
# Use Time(s):  94.09958529472351
# [T] TOP 1 8
# [T] TOP 5 44
# [T] TOP 10 89
# Epoch:  14 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 3 position: [70, 576, 991]
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1940 - val_loss: 0.1688
# Data parts  2 / 10 ----------------------------------------
#
# C value = 5 position: [18, 215, 410, 566, 682]
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1826 - val_loss: 0.1926
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.1843 - val_loss: 0.1834
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1921 - val_loss: 0.1800
# Data parts  5 / 10 ----------------------------------------
#
# C value = 3 position: [206, 566, 664]
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2967 - val_loss: 0.2209
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [359]
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2188 - val_loss: 0.2161
# Data parts  7 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2364 - val_loss: 0.2746
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2013 - val_loss: 0.1973
# Data parts  9 / 10 ----------------------------------------
#
# C value = 2 position: [339, 992]
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1981 - val_loss: 0.1864
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2279 - val_loss: 0.2696
# Find ranking of  1000  sentence pairs
# Use Time(s):  98.0814859867096
# [T] TOP 1 6
# [T] TOP 5 39
# [T] TOP 10 82
# Epoch:  15 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [286, 592]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1842 - val_loss: 0.1691
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [901]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1760 - val_loss: 0.1857
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [604]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.1845 - val_loss: 0.2057
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1866 - val_loss: 0.1931
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [729]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.1889 - val_loss: 0.1915
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [562, 573]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1766 - val_loss: 0.1778
# Data parts  7 / 10 ----------------------------------------
#
# C value = 2 position: [496, 530]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1728 - val_loss: 0.2362
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [131]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1656 - val_loss: 0.1695
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [542]
# ...
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [850]
# Train on 9000 samples, validate on 1000 samples
# Epoch 24/24
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  112.53270363807678
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  25 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [596, 629]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 2 position: [372, 476]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 3 position: [240, 513, 882]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
#
# C value = 3 position: [156, 307, 476]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 4 position: [14, 18, 562, 918]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [361]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 5 position: [149, 204, 215, 385, 495]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  116.44527697563171
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  26 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 14s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [593]
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 14s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 14s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [218, 605]
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
#
# C value = 3 position: [69, 526, 622]
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [144]
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [775]
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [528]
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [738]
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  120.60459971427917
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  27 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [44]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 14s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 3 position: [165, 599, 849]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [156]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [274]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [618, 930]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [617]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [593, 740]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [772]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 3 position: [208, 339, 599]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  128.00736784934998
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  28 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [145, 597]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 2 position: [408, 675]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [599]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [123, 330]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [18]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [790]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  130.44155144691467
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  29 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [235, 825]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [640, 839]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 3 position: [144, 168, 314]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [491, 936]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 2 position: [208, 527]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  125.77542233467102
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  30 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [733]
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [552]
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [307, 732]
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [53, 676]
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [902]
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [674]
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  122.99170994758606
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15, 7)
#plt.plot(tops[1],'r-*', label = "TOP-1: Trianing")
#plt.plot(tops[5],'b-*', label = "TOP-5: Trianing" )
#plt.plot(tops[10],'g-*', label = "TOP-10: Trianing")
plt.plot(tops_test[1],'r--', label = "TOP-1: Test")
plt.plot(tops_test[5],'b--', label = "TOP-5: Test")
plt.plot(tops_test[10],'g--', label = "TOP10: Test")
plt.ylabel('TOP Accuracy', fontsize=11)
plt.xlabel('Epoches', fontsize=11)
plt.title('TOP Accuracy vs Epoches')
plt.legend(loc = 2, fontsize=8)
plt.savefig('top1-5-10_e40_l0.eps', format='eps', dpi=1000)
plt.show()

# %%
model_lstm2.layers
# Out:
# [<keras.engine.topology.InputLayer at 0x7f8d1e91aba8>,
#  <keras.engine.topology.InputLayer at 0x7f8d1c863080>,
#  <keras.layers.wrappers.Bidirectional at 0x7f8d1e251c50>,
#  <keras.layers.wrappers.Bidirectional at 0x7f8c39735978>,
#  <keras.layers.merge.Dot at 0x7f8c39754320>,
#  <keras.layers.merge.Dot at 0x7f8c39754358>,
#  <keras.layers.merge.Dot at 0x7f8c393c1898>,
#  <keras.layers.merge.Dot at 0x7f8c392ae860>,
#  <keras.layers.core.Lambda at 0x7f8c392aea58>,
#  <keras.layers.merge.Concatenate at 0x7f8c39272e80>,
#  <keras.layers.core.Dense at 0x7f8c392c6cf8>,
#  <keras.layers.core.Dense at 0x7f8c3922a710>,
#  <keras.layers.merge.Add at 0x7f8c39242f98>,
#  <keras.layers.core.Dense at 0x7f8c39242fd0>,
#  <keras.layers.core.Dropout at 0x7f8c391f74e0>,
#  <keras.layers.core.Dense at 0x7f8c391f76a0>]

# %%
len(model_lstm2.layers)
# Out:
# 16

# %%
model_lstm2.layers[10]

# %%
plt.plot(train_loss[100:])
plt.plot(test_loss[100:])

# %% [markdown]
# # SGD

# %%
run keras_title_projattention_res.py
# Out:
# Using TensorFlow backend.
# maxlen 30 epoch 10 dim_lstm 200
# dim_Dense 50
# dropout_rate 0.0 , LSTM type: bi-lstm sum
# Activation function: ['relu', 'relu', 'relu']
# bias of y: 0
# loss_function: mse
# start: 0 end:
# ------------------------------
# Reading English Data: 72043
# Reading jp Data: 72043
# Merging the English and Japanes news dataframe...
# Drop the null line...
# False    72031
# True        12
# Name: en_article, dtype: int64
# Using the new test data to evaluate.......
# /home/R2016hwang/research/keras_title_projattention_res.py:439: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if token in model:
# /home/R2016hwang/research/keras_title_projattention_res.py:445: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   r.append(model[token])
# /home/R2016hwang/research/keras_title_projattention_res.py:600: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_evaluate['word2vec_en'] = df_pairs_evaluate['en_article'].apply(doc2embed, args=(model_en,))
# /home/R2016hwang/research/keras_title_projattention_res.py:443: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   r.append(np.array(model[token]).dot(translation_matrix))
# /home/R2016hwang/research/keras_title_projattention_res.py:602: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_evaluate['word2vec_jp'] = df_pairs_evaluate['jp_article'].apply(doc2embed, args=(model_jp, trans_jp_en))
# /home/R2016hwang/research/keras_title_projattention_res.py:604: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_evaluate['padding_en'] = df_pairs_evaluate['word2vec_en'].apply(padding, args=(TIME_STEP,))
# /home/R2016hwang/research/keras_title_projattention_res.py:606: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_evaluate['padding_jp'] = df_pairs_evaluate['word2vec_jp'].apply(padding, args=(TIME_STEP,))
# /home/R2016hwang/research/keras_title_projattention_res.py:617: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_sample['word2vec_en'] = df_pairs_sample['en_article'].apply(doc2embed, args=(model_en,))
# /home/R2016hwang/research/keras_title_projattention_res.py:619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_sample['word2vec_jp'] = df_pairs_sample['jp_article'].apply(doc2embed, args=(model_jp, trans_jp_en))
# 长度为零
# 长度为零
# 长度为零
# 长度为零
# 长度为零
# 长度为零
# 长度为零
# /home/R2016hwang/research/keras_title_projattention_res.py:622: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_sample['padding_en'] = df_pairs_sample['word2vec_en'].apply(padding, args=(TIME_STEP,))
# /home/R2016hwang/research/keras_title_projattention_res.py:624: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_sample['padding_jp'] = df_pairs_sample['word2vec_jp'].apply(padding, args=(TIME_STEP,))
# C value = 8 position: [4020, 10599, 15437, 20430, 31380, 32581, 38860, 43562]
# /home/R2016hwang/research/keras_title_projattention_res.py:747: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("ma...)`
#   model_lstm2 = Model(input=[input_1, input_2], output=main_output)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input_1 (InputLayer)       (None, 30, 200)      0
# __________________________________________________________________________________________________
# main_input_2 (InputLayer)       (None, 30, 200)      0
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 30, 200)      641600      main_input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 30, 200)      641600      main_input_2[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 30, 30)       0           bidirectional_1[0][0]
#                                                                  bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, 30, 30)       0           bidirectional_2[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dot_3 (Dot)                     (None, 30, 200)      0           dot_1[0][0]
#                                                                  bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dot_4 (Dot)                     (None, 30, 200)      0           dot_2[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 200)          0           bidirectional_1[0][0]
#                                                                  bidirectional_2[0][0]
#                                                                  dot_3[0][0]
#                                                                  dot_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 800)          0           lambda_1[0][0]
#                                                                  lambda_1[2][0]
#                                                                  lambda_1[1][0]
#                                                                  lambda_1[3][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 200)          160200      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 200)          160200      concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 200)          0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 50)           10050       add_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 50)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 1)            51          dropout_1[0][0]
# ==================================================================================================
# Total params: 1,613,701
# Trainable params: 1,613,701
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch:  1 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 4 position: [197, 479, 519, 603]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 21s 2ms/step - loss: 1.3477 - val_loss: 0.3148
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [677]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2385 - val_loss: 0.2006
# Data parts  3 / 10 ----------------------------------------
#
# C value = 3 position: [48, 628, 716]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 46.7581 - val_loss: 0.8936
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [834, 917]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.6377 - val_loss: 0.5425
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [196]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.5057 - val_loss: 0.5457
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [606]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.3819 - val_loss: 0.3479
# Data parts  7 / 10 ----------------------------------------
#
# C value = 3 position: [198, 222, 337]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.3438 - val_loss: 0.4118
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [186, 500]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2865 - val_loss: 0.3017
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2835 - val_loss: 0.3354
# Data parts  10 / 10 ----------------------------------------
#
# C value = 3 position: [127, 191, 497]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2720 - val_loss: 0.2741
# Find ranking of  1000  sentence pairs
# /home/R2016hwang/research/keras_title_projattention_res.py:186: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   model_1 = Model(input=[input_1, input_2], output=[lstm_out_1, lstm_out_2])
# /home/R2016hwang/research/keras_title_projattention_res.py:282: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("ma...)`
#   model_2 = Model(input=[input_1, input_2], output=main_output)
# Use Time(s):  70.34982895851135
# [T] TOP 1 3
# [T] TOP 5 16
# [T] TOP 10 42
# Epoch:  2 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [573, 600]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2374 - val_loss: 0.2523
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [646]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2169 - val_loss: 0.2050
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [581]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 18s 2ms/step - loss: 1.8271 - val_loss: 0.2676
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [316, 735]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2364 - val_loss: 0.2369
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [600, 686]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2299 - val_loss: 0.2861
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2037 - val_loss: 0.2130
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [107]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2031 - val_loss: 0.3152
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [608]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1911 - val_loss: 0.2002
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1804 - val_loss: 0.2437
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1724 - val_loss: 0.2068
# Find ranking of  1000  sentence pairs
# Use Time(s):  72.74724507331848
# [T] TOP 1 9
# [T] TOP 5 48
# [T] TOP 10 93
# Epoch:  3 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 3 position: [40, 723, 847]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1642 - val_loss: 0.1638
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.1576 - val_loss: 0.1526
# Data parts  3 / 10 ----------------------------------------
#
# C value = 2 position: [217, 452]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1841 - val_loss: 0.1715
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [279]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1461 - val_loss: 0.1704
# Data parts  5 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1514 - val_loss: 0.2043
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [405, 971]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1408 - val_loss: 0.1536
# Data parts  7 / 10 ----------------------------------------
#
# C value = 3 position: [317, 385, 604]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1348 - val_loss: 0.1875
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [598, 874]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1277 - val_loss: 0.1681
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [954]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.1261 - val_loss: 0.2036
# Data parts  10 / 10 ----------------------------------------
#
# C value = 2 position: [266, 496]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1237 - val_loss: 0.1609
# Find ranking of  1000  sentence pairs
# Use Time(s):  70.62362837791443
# [T] TOP 1 14
# [T] TOP 5 77
# [T] TOP 10 165
# Epoch:  4 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 3 position: [296, 822, 963]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1184 - val_loss: 0.1374
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1181 - val_loss: 0.1229
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [519]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1386 - val_loss: 0.1558
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [468, 470]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1215 - val_loss: 0.1572
# Data parts  5 / 10 ----------------------------------------
#
# C value = 3 position: [525, 846, 900]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1228 - val_loss: 0.1806
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [48, 592]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1149 - val_loss: 0.1303
# Data parts  7 / 10 ----------------------------------------
#
# C value = 2 position: [413, 426]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1079 - val_loss: 0.1740
# Data parts  8 / 10 ----------------------------------------
#
# C value = 3 position: [388, 605, 881]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1022 - val_loss: 0.1368
# Data parts  9 / 10 ----------------------------------------
#
# C value = 2 position: [258, 742]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1010 - val_loss: 0.1696
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [410]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0999 - val_loss: 0.1449
# Find ranking of  1000  sentence pairs
# Use Time(s):  74.68182134628296
# [T] TOP 1 17
# [T] TOP 5 115
# [T] TOP 10 208
# Epoch:  5 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [612]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0923 - val_loss: 0.1224
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0935 - val_loss: 0.1048
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1067 - val_loss: 0.1431
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [921]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.1044 - val_loss: 0.1458
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [594]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.1008 - val_loss: 0.1371
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [340]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0942 - val_loss: 0.1093
# Data parts  7 / 10 ----------------------------------------
#
# C value = 2 position: [90, 220]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0869 - val_loss: 0.1377
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.0813 - val_loss: 0.1186
# Data parts  9 / 10 ----------------------------------------
#
# C value = 2 position: [321, 598]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0816 - val_loss: 0.1511
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [594]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0792 - val_loss: 0.1237
# Find ranking of  1000  sentence pairs
# Use Time(s):  72.92990398406982
# [T] TOP 1 31
# [T] TOP 5 171
# [T] TOP 10 272
# Epoch:  6 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0730 - val_loss: 0.1058
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [361]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0749 - val_loss: 0.0865
# Data parts  3 / 10 ----------------------------------------
#
# C value = 3 position: [459, 649, 751]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0691 - val_loss: 0.1032
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [409, 604]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0663 - val_loss: 0.1126
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [435, 714]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0740 - val_loss: 0.1198
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [641, 966]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0709 - val_loss: 0.1025
# Data parts  7 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0658 - val_loss: 0.1268
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0627 - val_loss: 0.1023
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [288]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0641 - val_loss: 0.1445
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [16]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0621 - val_loss: 0.1135
# Find ranking of  1000  sentence pairs
# Use Time(s):  75.86293458938599
# [T] TOP 1 34
# [T] TOP 5 189
# [T] TOP 10 317
# Epoch:  7 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [528]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0583 - val_loss: 0.0911
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [539]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0613 - val_loss: 0.0769
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0563 - val_loss: 0.0974
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [593]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0548 - val_loss: 0.1060
# Data parts  5 / 10 ----------------------------------------
#
# C value = 3 position: [111, 295, 466]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0602 - val_loss: 0.1040
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [274]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0584 - val_loss: 0.0871
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [196]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.0566 - val_loss: 0.1226
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0543 - val_loss: 0.0897
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0527 - val_loss: 0.1400
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0535 - val_loss: 0.1103
# Find ranking of  1000  sentence pairs
# Use Time(s):  75.58658385276794
# [T] TOP 1 49
# [T] TOP 5 213
# [T] TOP 10 352
# Epoch:  8 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [859]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0504 - val_loss: 0.0813
# Data parts  2 / 10 ----------------------------------------
#
# C value = 2 position: [183, 819]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0507 - val_loss: 0.0713
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0474 - val_loss: 0.0819
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [256]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0479 - val_loss: 0.0901
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [602]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0525 - val_loss: 0.1011
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0519 - val_loss: 0.0779
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [267]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0476 - val_loss: 0.1257
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0477 - val_loss: 0.0794
# Data parts  9 / 10 ----------------------------------------
#
# C value = 3 position: [386, 598, 877]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0447 - val_loss: 0.1573
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0479 - val_loss: 0.1003
# Find ranking of  1000  sentence pairs
# Use Time(s):  77.00273847579956
# [T] TOP 1 51
# [T] TOP 5 240
# [T] TOP 10 373
# Epoch:  9 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [772]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0460 - val_loss: 0.0869
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0434 - val_loss: 0.0642
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [976]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0551 - val_loss: 0.0713
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [525]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0430 - val_loss: 0.0818
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [136]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.0500 - val_loss: 0.1007
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [73, 369]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0451 - val_loss: 0.0682
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [827]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0436 - val_loss: 0.0995
# Data parts  8 / 10 ----------------------------------------
#
# C value = 3 position: [209, 583, 594]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0471 - val_loss: 0.0827
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [472]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0522 - val_loss: 0.1509
# Data parts  10 / 10 ----------------------------------------
#
# C value = 3 position: [22, 222, 920]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0449 - val_loss: 0.0856
# Find ranking of  1000  sentence pairs
# Use Time(s):  73.9399836063385
# [T] TOP 1 64
# [T] TOP 5 263
# [T] TOP 10 405
# Epoch:  10 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [109, 347]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0404 - val_loss: 0.0593
# Data parts  2 / 10 ----------------------------------------
#
# C value = 2 position: [54, 388]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0396 - val_loss: 0.0617
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 9.8489 - val_loss: 3.5606
# Data parts  4 / 10 ----------------------------------------
#
# C value = 3 position: [196, 597, 894]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 18s 2ms/step - loss: 96.8824 - val_loss: 0.3114
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [361, 956]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2874 - val_loss: 0.2750
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [18]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2797 - val_loss: 0.2732
# Data parts  7 / 10 ----------------------------------------
#
# C value = 3 position: [190, 637, 786]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2839 - val_loss: 0.2686
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [422, 573]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.4563 - val_loss: 0.2715
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.3067 - val_loss: 0.2793
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.3233 - val_loss: 0.2513
# Find ranking of  1000  sentence pairs
# Use Time(s):  78.57233214378357
# [T] TOP 1 0
# [T] TOP 5 4
# [T] TOP 10 10
# Epoch:  11 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [690]
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2811 - val_loss: 0.2688
# Data parts  2 / 10 ----------------------------------------
#
# C value = 3 position: [620, 655, 980]
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2650 - val_loss: 0.2818
# Data parts  3 / 10 ----------------------------------------
#
# C value = 4 position: [136, 172, 600, 724]
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2628 - val_loss: 0.2598
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [605]
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2611 - val_loss: 0.2587
# Data parts  5 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2654 - val_loss: 0.2574
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2571 - val_loss: 0.2592
# Data parts  7 / 10 ----------------------------------------
#
# C value = 2 position: [45, 63]
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2612 - val_loss: 0.2853
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [593, 893]
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2605 - val_loss: 0.2642
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2591 - val_loss: 0.2602
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [148]
# Train on 9000 samples, validate on 1000 samples
# Epoch 11/11
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2540 - val_loss: 0.2524
# Find ranking of  1000  sentence pairs
# Use Time(s):  80.28821015357971
# [T] TOP 1 2
# [T] TOP 5 7
# [T] TOP 10 12
# Epoch:  12 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2549 - val_loss: 0.2555
# Data parts  2 / 10 ----------------------------------------
#
# C value = 4 position: [382, 681, 727, 957]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 14s 2ms/step - loss: 0.2556 - val_loss: 0.2652
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2554 - val_loss: 0.2552
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [168, 721]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2521 - val_loss: 0.2590
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [179]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2552 - val_loss: 0.2555
# Data parts  6 / 10 ----------------------------------------
#
# C value = 3 position: [58, 189, 409]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2524 - val_loss: 0.2655
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [664]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2533 - val_loss: 0.2771
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2533 - val_loss: 0.2518
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [170]
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2517 - val_loss: 0.2562
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 12/12
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2516 - val_loss: 0.2478
# Find ranking of  1000  sentence pairs
# Use Time(s):  80.65896654129028
# [T] TOP 1 3
# [T] TOP 5 6
# [T] TOP 10 16
# Epoch:  13 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [81, 890]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2493 - val_loss: 0.2515
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2485 - val_loss: 0.2535
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2493 - val_loss: 0.2469
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [197, 963]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2493 - val_loss: 0.2461
# Data parts  5 / 10 ----------------------------------------
#
# C value = 3 position: [159, 266, 456]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2496 - val_loss: 0.2635
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [298, 466]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2496 - val_loss: 0.2502
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [281]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2463 - val_loss: 0.2552
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [160, 643]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2476 - val_loss: 0.2409
# Data parts  9 / 10 ----------------------------------------
#
# C value = 2 position: [537, 682]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2487 - val_loss: 0.2503
# Data parts  10 / 10 ----------------------------------------
#
# C value = 2 position: [125, 324]
# Train on 9000 samples, validate on 1000 samples
# Epoch 13/13
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2488 - val_loss: 0.2483
# Find ranking of  1000  sentence pairs
# Use Time(s):  82.87321043014526
# [T] TOP 1 0
# [T] TOP 5 7
# [T] TOP 10 13
# Epoch:  14 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [103, 605]
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2424 - val_loss: 0.2449
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2440 - val_loss: 0.2495
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [78]
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2477 - val_loss: 0.2514
# Data parts  4 / 10 ----------------------------------------
#
# C value = 3 position: [269, 596, 741]
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2460 - val_loss: 0.2456
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [120]
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2457 - val_loss: 0.2523
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2433 - val_loss: 0.2479
# Data parts  7 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2422 - val_loss: 0.2596
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [901]
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2464 - val_loss: 0.2536
# Data parts  9 / 10 ----------------------------------------
#
# C value = 2 position: [168, 437]
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2451 - val_loss: 0.2390
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 14/14
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2444 - val_loss: 0.2450
# Find ranking of  1000  sentence pairs
# Use Time(s):  80.19268870353699
# [T] TOP 1 1
# [T] TOP 5 9
# [T] TOP 10 19
# Epoch:  15 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [705, 761]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2380 - val_loss: 0.2377
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [596]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2374 - val_loss: 0.2478
# Data parts  3 / 10 ----------------------------------------
#
# C value = 2 position: [104, 625]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2421 - val_loss: 0.2416
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [76]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2389 - val_loss: 0.2374
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [337, 981]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2391 - val_loss: 0.2506
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [160, 188]
# Train on 9000 samples, validate on 1000 samples
# Epoch 15/15
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2378 - val_loss: 0.2399
# ...
# Data parts  10 / 10 ----------------------------------------
#
# C value = 2 position: [532, 551]
# Train on 9000 samples, validate on 1000 samples
# Epoch 24/24
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  87.19258570671082
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  25 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 5 position: [25, 37, 196, 243, 718]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [352]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 3 position: [5, 505, 709]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
#
# C value = 4 position: [464, 468, 512, 603]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [770, 826]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [284]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [331]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 2 position: [605, 619]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [921]
# Train on 9000 samples, validate on 1000 samples
# Epoch 25/25
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  89.66930866241455
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  26 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [862]
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 2 position: [641, 705]
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [570, 954]
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [318, 909]
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 26/26
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  89.05555725097656
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  27 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [8, 350]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 3 position: [353, 690, 945]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [992]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [129, 266]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [456, 763]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 2 position: [597, 653]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [814]
# Train on 9000 samples, validate on 1000 samples
# Epoch 27/27
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  87.4802975654602
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  28 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [120]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [572]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 2 position: [11, 678]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [507, 829]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [557]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [277]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [761]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 3 position: [461, 599, 749]
# Train on 9000 samples, validate on 1000 samples
# Epoch 28/28
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  85.95384645462036
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  29 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [819]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 2 position: [78, 651]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 3 position: [146, 464, 703]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [453, 840]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [606]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [136]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [182, 598]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 2 position: [217, 736]
# Train on 9000 samples, validate on 1000 samples
# Epoch 29/29
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  88.74906182289124
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
# Epoch:  30 / 30 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 5 position: [106, 603, 619, 882, 969]
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [20]
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  4 / 10 ----------------------------------------
#
# C value = 3 position: [318, 598, 602]
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  5 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [495, 993]
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 18s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [464]
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  8 / 10 ----------------------------------------
#
# C value = 4 position: [98, 110, 593, 603]
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2500 - val_loss: 0.2500
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 30/30
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.2501 - val_loss: 0.2500
# Find ranking of  1000  sentence pairs
# Use Time(s):  91.9928207397461
# [T] TOP 1 0
# [T] TOP 5 0
# [T] TOP 10 0
