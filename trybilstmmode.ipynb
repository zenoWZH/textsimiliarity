# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
run keras_title_projection.py   ##bi_lstm_mode = concat
# Out:
# Using TensorFlow backend.
# maxlen 30 epoch 10 dim_lstm 200
# dim_Dense 800
# dropout_rate 0.0 , LSTM type: bi-lstm concat
# Activation function: ['relu', 'relu', 'relu']
# bias of y: 0
# loss_function: mse
# start: 0 end:
# ------------------------------
# Reading English Data: 72043
# Reading jp Data: 72043
# Merging the English and Japanes news dataframe...
# Drop the null line...
# False    72031
# True        12
# Name: en_article, dtype: int64
# Using the new test data to evaluate.......
# /home/R2016hwang/research/keras_title_projection.py:364: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if token in model:
# /home/R2016hwang/research/keras_title_projection.py:370: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   r.append(model[token])
# /home/R2016hwang/research/keras_title_projection.py:506: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_evaluate['word2vec_en'] = df_pairs_evaluate['en_article'].apply(doc2embed, args=(model_en,))
# /home/R2016hwang/research/keras_title_projection.py:368: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   r.append(np.array(model[token]).dot(translation_matrix))
# /home/R2016hwang/research/keras_title_projection.py:508: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_evaluate['word2vec_jp'] = df_pairs_evaluate['jp_article'].apply(doc2embed, args=(model_jp, trans_jp_en))
# /home/R2016hwang/research/keras_title_projection.py:510: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_evaluate['padding_en'] = df_pairs_evaluate['word2vec_en'].apply(padding, args=(TIME_STEP,))
# /home/R2016hwang/research/keras_title_projection.py:512: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_evaluate['padding_jp'] = df_pairs_evaluate['word2vec_jp'].apply(padding, args=(TIME_STEP,))
# /home/R2016hwang/research/keras_title_projection.py:523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_sample['word2vec_en'] = df_pairs_sample['en_article'].apply(doc2embed, args=(model_en,))
# /home/R2016hwang/research/keras_title_projection.py:525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_sample['word2vec_jp'] = df_pairs_sample['jp_article'].apply(doc2embed, args=(model_jp, trans_jp_en))
# 长度为零
# 长度为零
# 长度为零
# 长度为零
# 长度为零
# 长度为零
# 长度为零
# /home/R2016hwang/research/keras_title_projection.py:528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_sample['padding_en'] = df_pairs_sample['word2vec_en'].apply(padding, args=(TIME_STEP,))
# /home/R2016hwang/research/keras_title_projection.py:530: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_pairs_sample['padding_jp'] = df_pairs_sample['word2vec_jp'].apply(padding, args=(TIME_STEP,))
# C value = 6 position: [2646, 16674, 22530, 35019, 36747, 46648]
# /home/R2016hwang/research/keras_title_projection.py:587: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("ma...)`
#   model_lstm2 = Model(input=[input_1, input_2], output=main_output)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input_1 (InputLayer)       (None, 30, 200)      0
# __________________________________________________________________________________________________
# main_input_2 (InputLayer)       (None, 30, 200)      0
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 400)          641600      main_input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 400)          641600      main_input_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 800)          0           bidirectional_1[0][0]
#                                                                  bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 800)          640800      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 800)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 1)            801         dropout_1[0][0]
# ==================================================================================================
# Total params: 1,924,801
# Trainable params: 1,924,801
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch:  1 / 10 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [596]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 20s 2ms/step - loss: 0.1252 - val_loss: 0.0778
# Data parts  2 / 10 ----------------------------------------
#
# C value = 3 position: [288, 826, 836]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0873 - val_loss: 0.0816
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0760 - val_loss: 0.0750
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [37, 837]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0683 - val_loss: 0.0793
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [462, 598]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0684 - val_loss: 0.0817
# Data parts  6 / 10 ----------------------------------------
#
# C value = 3 position: [18, 533, 810]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0645 - val_loss: 0.0662
# Data parts  7 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0610 - val_loss: 0.1221
# Data parts  8 / 10 ----------------------------------------
#
# C value = 3 position: [45, 315, 405]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0598 - val_loss: 0.0648
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [772]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0557 - val_loss: 0.0867
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [71]
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/1
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0551 - val_loss: 0.0549
# /home/R2016hwang/research/keras_title_projection.py:157: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`
#   model_1 = Model(input=[input_1, input_2], output=[lstm_out_1, lstm_out_2])
# /home/R2016hwang/research/keras_title_projection.py:209: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("ma...)`
#   model_2 = Model(input=[input_1, input_2], output=main_output)
# TOP 1 80
# [T] TOP 1 143
# TOP 5 226
# [T] TOP 5 456
# TOP 10 309
# [T] TOP 10 623
# Epoch:  2 / 10 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 3 position: [121, 236, 599]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0457 - val_loss: 0.0449
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [948]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0467 - val_loss: 0.0588
# Data parts  3 / 10 ----------------------------------------
#
# C value = 1 position: [828]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0414 - val_loss: 0.0559
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [366]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0404 - val_loss: 0.0583
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [480, 848]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0425 - val_loss: 0.0771
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [11, 510]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0393 - val_loss: 0.0541
# Data parts  7 / 10 ----------------------------------------
#
# C value = 3 position: [551, 665, 852]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0379 - val_loss: 0.0784
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [17]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0386 - val_loss: 0.0501
# Data parts  9 / 10 ----------------------------------------
#
# C value = 3 position: [212, 621, 955]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0359 - val_loss: 0.0731
# Data parts  10 / 10 ----------------------------------------
#
# C value = 2 position: [507, 606]
# Train on 9000 samples, validate on 1000 samples
# Epoch 2/2
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0366 - val_loss: 0.0460
# TOP 1 89
# [T] TOP 1 179
# TOP 5 249
# [T] TOP 5 464
# TOP 10 330
# [T] TOP 10 618
# Epoch:  3 / 10 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0327 - val_loss: 0.0428
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [303]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0345 - val_loss: 0.0506
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0314 - val_loss: 0.0468
# Data parts  4 / 10 ----------------------------------------
#
# C value = 2 position: [250, 421]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.0287 - val_loss: 0.0465
# Data parts  5 / 10 ----------------------------------------
#
# C value = 2 position: [24, 748]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 14s 2ms/step - loss: 0.0305 - val_loss: 0.0693
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [782]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.0287 - val_loss: 0.0498
# Data parts  7 / 10 ----------------------------------------
#
# C value = 3 position: [11, 78, 877]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0281 - val_loss: 0.0815
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0287 - val_loss: 0.0496
# Data parts  9 / 10 ----------------------------------------
#
# C value = 3 position: [34, 693, 802]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0284 - val_loss: 0.0836
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [321]
# Train on 9000 samples, validate on 1000 samples
# Epoch 3/3
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0275 - val_loss: 0.0424
# TOP 1 91
# [T] TOP 1 186
# TOP 5 251
# [T] TOP 5 471
# TOP 10 343
# [T] TOP 10 640
# Epoch:  4 / 10 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [697, 779]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0254 - val_loss: 0.0365
# Data parts  2 / 10 ----------------------------------------
#
# C value = 2 position: [275, 599]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0261 - val_loss: 0.0460
# Data parts  3 / 10 ----------------------------------------
#
# C value = 2 position: [170, 791]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0242 - val_loss: 0.0479
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0228 - val_loss: 0.0475
# Data parts  5 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0230 - val_loss: 0.0683
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0225 - val_loss: 0.0468
# Data parts  7 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0215 - val_loss: 0.0687
# Data parts  8 / 10 ----------------------------------------
#
# C value = 3 position: [219, 321, 334]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0234 - val_loss: 0.0469
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0214 - val_loss: 0.0705
# Data parts  10 / 10 ----------------------------------------
#
# C value = 2 position: [93, 936]
# Train on 9000 samples, validate on 1000 samples
# Epoch 4/4
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0218 - val_loss: 0.0449
# TOP 1 98
# [T] TOP 1 195
# TOP 5 240
# [T] TOP 5 465
# TOP 10 330
# [T] TOP 10 625
# Epoch:  5 / 10 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0198 - val_loss: 0.0418
# Data parts  2 / 10 ----------------------------------------
#
# C value = 3 position: [187, 196, 706]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0207 - val_loss: 0.0442
# Data parts  3 / 10 ----------------------------------------
#
# C value = 3 position: [316, 622, 656]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0193 - val_loss: 0.0470
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0184 - val_loss: 0.0456
# Data parts  5 / 10 ----------------------------------------
#
# C value = 1 position: [849]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0183 - val_loss: 0.0750
# Data parts  6 / 10 ----------------------------------------
#
# C value = 3 position: [126, 152, 276]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0178 - val_loss: 0.0471
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [937]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0177 - val_loss: 0.0619
# Data parts  8 / 10 ----------------------------------------
#
# C value = 3 position: [200, 507, 597]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0191 - val_loss: 0.0507
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0178 - val_loss: 0.0712
# Data parts  10 / 10 ----------------------------------------
#
# C value = 3 position: [6, 478, 869]
# Train on 9000 samples, validate on 1000 samples
# Epoch 5/5
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0176 - val_loss: 0.0480
# TOP 1 91
# [T] TOP 1 198
# TOP 5 244
# [T] TOP 5 478
# TOP 10 331
# [T] TOP 10 627
# Epoch:  6 / 10 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [634, 708]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0166 - val_loss: 0.0360
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [259]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0172 - val_loss: 0.0462
# Data parts  3 / 10 ----------------------------------------
#
# C value = 2 position: [41, 835]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0165 - val_loss: 0.0422
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0153 - val_loss: 0.0474
# Data parts  5 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0157 - val_loss: 0.0659
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [955, 974]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0152 - val_loss: 0.0490
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [930]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0152 - val_loss: 0.0657
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [174]
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0164 - val_loss: 0.0473
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0156 - val_loss: 0.0641
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 6/6
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0148 - val_loss: 0.0445
# TOP 1 99
# [T] TOP 1 200
# TOP 5 241
# [T] TOP 5 491
# TOP 10 326
# [T] TOP 10 631
# Epoch:  7 / 10 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 3 position: [386, 598, 798]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0146 - val_loss: 0.0449
# Data parts  2 / 10 ----------------------------------------
#
# C value = 1 position: [673]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0153 - val_loss: 0.0459
# Data parts  3 / 10 ----------------------------------------
#
# C value = 3 position: [156, 600, 695]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0148 - val_loss: 0.0452
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [744]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0137 - val_loss: 0.0467
# Data parts  5 / 10 ----------------------------------------
#
# C value = 3 position: [104, 407, 865]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0136 - val_loss: 0.0747
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [48]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0132 - val_loss: 0.0478
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [341]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0123 - val_loss: 0.0661
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0147 - val_loss: 0.0476
# Data parts  9 / 10 ----------------------------------------
#
# C value = 1 position: [141]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0140 - val_loss: 0.0826
# Data parts  10 / 10 ----------------------------------------
#
# C value = 1 position: [246]
# Train on 9000 samples, validate on 1000 samples
# Epoch 7/7
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0132 - val_loss: 0.0465
# TOP 1 104
# [T] TOP 1 183
# TOP 5 251
# [T] TOP 5 472
# TOP 10 336
# [T] TOP 10 638
# Epoch:  8 / 10 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [675, 695]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0132 - val_loss: 0.0423
# Data parts  2 / 10 ----------------------------------------
#
# C value = 2 position: [95, 892]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0136 - val_loss: 0.0441
# Data parts  3 / 10 ----------------------------------------
#
# C value = 2 position: [15, 156]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0130 - val_loss: 0.0441
# Data parts  4 / 10 ----------------------------------------
#
# C value = 1 position: [15]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0124 - val_loss: 0.0459
# Data parts  5 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0126 - val_loss: 0.0740
# Data parts  6 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0115 - val_loss: 0.0473
# Data parts  7 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0115 - val_loss: 0.0642
# Data parts  8 / 10 ----------------------------------------
#
# C value = 1 position: [505]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0136 - val_loss: 0.0446
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0129 - val_loss: 0.0727
# Data parts  10 / 10 ----------------------------------------
#
# C value = 2 position: [387, 781]
# Train on 9000 samples, validate on 1000 samples
# Epoch 8/8
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0123 - val_loss: 0.0481
# TOP 1 90
# [T] TOP 1 184
# TOP 5 247
# [T] TOP 5 466
# TOP 10 335
# [T] TOP 10 623
# Epoch:  9 / 10 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 1 position: [604]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0119 - val_loss: 0.0447
# Data parts  2 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0123 - val_loss: 0.0451
# Data parts  3 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0116 - val_loss: 0.0425
# Data parts  4 / 10 ----------------------------------------
#
# C value = 3 position: [416, 600, 922]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0107 - val_loss: 0.0452
# Data parts  5 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0114 - val_loss: 0.0759
# Data parts  6 / 10 ----------------------------------------
#
# C value = 2 position: [328, 717]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0103 - val_loss: 0.0451
# Data parts  7 / 10 ----------------------------------------
#
# C value = 2 position: [525, 603]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0100 - val_loss: 0.0661
# Data parts  8 / 10 ----------------------------------------
#
# C value = 2 position: [613, 784]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.0121 - val_loss: 0.0446
# Data parts  9 / 10 ----------------------------------------
#
# C value = 3 position: [255, 333, 670]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 15s 2ms/step - loss: 0.0117 - val_loss: 0.0699
# Data parts  10 / 10 ----------------------------------------
#
# C value = 2 position: [354, 711]
# Train on 9000 samples, validate on 1000 samples
# Epoch 9/9
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0106 - val_loss: 0.0509
# TOP 1 88
# [T] TOP 1 194
# TOP 5 251
# [T] TOP 5 467
# TOP 10 333
# [T] TOP 10 632
# Epoch:  10 / 10 ----------------------------------------
#
# Data parts  1 / 10 ----------------------------------------
#
# C value = 2 position: [381, 526]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0112 - val_loss: 0.0391
# Data parts  2 / 10 ----------------------------------------
#
# C value = 2 position: [383, 566]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0114 - val_loss: 0.0478
# Data parts  3 / 10 ----------------------------------------
#
# C value = 2 position: [135, 596]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0113 - val_loss: 0.0424
# Data parts  4 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0099 - val_loss: 0.0464
# Data parts  5 / 10 ----------------------------------------
#
# C value = 3 position: [186, 325, 567]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0103 - val_loss: 0.0741
# Data parts  6 / 10 ----------------------------------------
#
# C value = 1 position: [604]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0093 - val_loss: 0.0461
# Data parts  7 / 10 ----------------------------------------
#
# C value = 1 position: [955]
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0093 - val_loss: 0.0699
# Data parts  8 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 16s 2ms/step - loss: 0.0117 - val_loss: 0.0473
# Data parts  9 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0104 - val_loss: 0.0664
# Data parts  10 / 10 ----------------------------------------
#
# C value = 0 position: []
# Train on 9000 samples, validate on 1000 samples
# Epoch 10/10
# 9000/9000 [==============================] - 17s 2ms/step - loss: 0.0102 - val_loss: 0.0526
# TOP 1 95
# [T] TOP 1 188
# TOP 5 243
# [T] TOP 5 480
# TOP 10 332
# [T] TOP 10 628

# %%
plt.plot(train_loss)
plt.plot(test_loss)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15, 7)
#plt.plot(tops[1],'r-*', label = "TOP-1: Trianing")
#plt.plot(tops[5],'b-*', label = "TOP-5: Trianing" )
#plt.plot(tops[10],'g-*', label = "TOP-10: Trianing")
plt.plot(tops_test[1],'r--', label = "TOP-1: Test")
plt.plot(tops_test[5],'b--', label = "TOP-5: Test")
plt.plot(tops_test[10],'g--', label = "TOP10: Test")
plt.ylabel('TOP Accuracy', fontsize=11)
plt.xlabel('Epoches', fontsize=11)
plt.title('TOP Accuracy vs Epoches')
plt.legend(loc = 2, fontsize=8)
plt.savefig('top1-5-10_e40_l0.eps', format='eps', dpi=1000)
plt.show()

# %%
type(tops_test[1])
# Out:
# list

# %%
import numpy as np

# %%
np.average(np.array(tops_test[1][5:]))
# Out:
# 189.8

# %%
np.average(np.array(tops_test[5][5:]))
# Out:
# 475.2

# %%
np.average(np.array(tops_test[10][5:]))
# Out:
# 630.4
